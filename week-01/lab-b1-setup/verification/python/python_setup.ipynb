# %% [markdown]
# # CS 3035 Python Setup Verification
# Run the code cell using the `CS3035` kernel.

# %%
import platform

print("Hello, CS 3035!")
print(f"Python version: {platform.python_version()}")
