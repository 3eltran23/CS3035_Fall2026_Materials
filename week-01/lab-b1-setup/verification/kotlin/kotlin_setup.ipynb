// %% [markdown]
// # CS 3035 Kotlin Setup Verification
// Run the code cell using Kotlin Notebook in IntelliJ IDEA.

// %%
println("Hello, CS 3035!")
println("Kotlin version: ${KotlinVersion.CURRENT}")
