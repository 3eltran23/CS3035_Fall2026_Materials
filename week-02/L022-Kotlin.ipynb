// %% [markdown]
// # Lecture 2.2: Kotlin Fundamentals

// %% [markdown]
// * Kotlin is a modern programming language that runs on the Java Virtual Machine (JVM) and beyond.
// * It is a general-purpose, concise, safe, and pragmatic language.
// * It is used to build mobile, server-side, and desktop applications, among many others.

// %%
data class Person(            // Data class
    val name: String,        // Read-only property
    val age: Int? = null     // Nullable type (Int?) - the default value for the argument
)

fun main(){                 //Top-level function
    val persons = listOf(
        Person("Alice", age = 29), //Name argument
        Person("Bob"),  // Trailing comma
    )

    val  oldest = persons.maxBy { // Lambda expression
        it.age ?: 0               // Null-coalescing Elvis operator
    }
    println("The oldest is: $oldest")  // string template
}
main()

// %% [markdown]
// Our first Kotlin code snippet demonstrates how to create a collection in Kotlin, populate it with `Person` objects, and then find the oldest person in the collection, using default values when no `age` is specified.
//
// * When creating the list of people, Bob’s age is omitted, so `null` is used as the default value.
// * To find the oldest person in the list, the `maxBy` function is used.
// * The lambda expression passed to the function takes one parameter, implicitly named `it` by default (although you can assign other name if desired).
// * The Elvis operator (`?:`) returns `0` if `age` is `null`. Because Bob’s age isn’t specified, it defaults to `0` during the comparison.

// %% [markdown]
// ## Kotlin's Primary Traits
//
// - Kotlin is a **multi-paradigm** language.
// - It is **statically typed**, meaning many errors can be caught at compile time instead of at runtime.
// - It combines ideas from **object-oriented (OO)** and **functional** programming, helping you write elegant code and use powerful abstractions.
// - It provides strong support for **asynchronous programming**, which is essential in many modern development domains.

// %% [markdown]
// ### Kotlin Use Cases
//
// Common Kotlin use cases include the following:
//
// - Building mobile applications that run on Android devices
// - Developing server-side systems (e.g., backends for web applications)

// %% [markdown]
// ### Static Typing
//
// Kotlin is **statically typed**, meaning many errors can be caught at compile time instead of at runtime. The main advantages include:
//
// - **Performance**: Method calls are faster.
// - **Reliability**: The compiler uses types to verify program consistency, reducing the chance of runtime crashes.
// - **Maintainability**: Working with unfamiliar code is easier because types make the structure and intent clearer.
// - **Tool support**: Enables reliable refactoring, precise code completion, and advanced IDE features.
//
// In contrast, **dynamically typed** languages such as Python or JavaScript allow variables and functions to store or return values of any type, resolving method and field references at runtime. The disadvantage is that issues like misspelled names or invalid parameters cannot be detected during compilation and may lead to runtime errors.
//
// > **Important:** Kotlin does not require explicit type declarations for every variable. In many cases, the type is automatically inferred from the context, allowing you to omit the type while still benefiting from static typing.

// %%
val x: Int = 1 // You can specify the variable type explicitly.
val y  = 1 // But often, you don't have specify it.
println(x and y)
// Out:
// 1

// %% [markdown]
// ### Final Goal: Combining Functional and Object-Oriented Programming
//
// As a multiparadigm programming language. Kotlin combines *object-oriented* approach with the *functional programming style*

// %% [markdown]
// ##  Basic elements: Variables

// %% [markdown]
// ### Hello, World!
// Here is a simple program that prints "Hello, world!":

// %%
fun main() {
    println("Hello, World!")
}

main()
// Out:
// Hello, World!

// %% [markdown]
// In Kotlin:
//
// - `fun` is used to **declare** a function.
// - The `main()` function is where your program **starts execution**.
//   - Just like in other programming languages such as Java, the entry point of a Kotlin application is the `main` function.
//   - This function can accept a variable number of `String` arguments, but these arguments can be omitted when they are not needed.
// - The body of a function is written within **curly braces** `{}`.
// - Kotlin allows you to **omit semicolons** at the end of lines.

// %%
fun main(args: Array<String>) {
    println("Hello, world!")
}
main()
// Out:
// Hello, World!

// %%
fun main() = println("Hello, world!")
main()
// Out:
// Hello, world!

// %% [markdown]
// ### Variables in Kotlin
//
// Kotlin uses two keywords to control whether a variable can be reassigned:
//
// - **`val`** → *read-only reference*
//   Assigned once and cannot be reassigned (similar to `final` in Java).
//
// - **`var`** → *reassignable reference (mutable)*
//   Can be reassigned after initialization (like a regular non-`final` variable in Java).
//
// > Use `val` by default, and `var` only when mutation is necessary.

// %% [markdown]
// To assign a value, use the assignment operator `=`.
//
// For example:

// %%
val popcorn = 5    // There are 5 boxes of popcorn
val hotdog = 7     // There are 7 hotdogs
var customers = 10 // There are 10 customers in the queue

// Some customers leave the queue
customers = 8
println(customers)
// Out:
// 8

// %% [markdown]
// >> As `customers` is a mutable variable, its value can be reassigned after declaration.

// %% [markdown]
// ### String templates

// %% [markdown]
// Kotlin uses **string templates** to easily print variables and expressions to standard output.
//
// - Strings are written inside double quotes `" "`
// - Template expressions start with a dollar sign `$`
// - Variables can be embedded directly in strings
// - Expressions must be wrapped in `{}`

// %%
val customers = 10
println("There are $customers customers")
// There are 10 customers

println("There are ${customers + 1} customers")
// There are 11 customers
// Out:
// There are 10 customers
// There are 11 customers

// %% [markdown]
// ### Basic Types
//
// - Every variable and data structure in Kotlin has a **type**
// - Types define:
//   - What operations are allowed
//   - What functions and properties are available
// - The compiler uses types to enforce **correct usage** of variables
//
// ### Type Inference
// - Kotlin can automatically determine a variable’s type
// - This is called **type inference**

// %%
var customers = 10

// Some customers leave the queue
customers = 8

customers = customers + 3 // Example of addition: 11
customers += 7            // Example of addition: 18
customers -= 3            // Example of subtraction: 15
customers *= 2            // Example of multiplication: 30
customers /= 3            // Example of division: 10

println(customers) // 10
// Out:
// 10

// %% [markdown]
// >`+=`, `-=`, `*=`, `/=`, and `%=` are augmented assignment operators. For more information, see [Augmented assignments](https://kotlinlang.org/docs/operator-overloading.html#augmented-assignments).

// %% [markdown]
// | Category | Basic types | Example code |
// |---|---|---|
// | [Integers](https://kotlinlang.org/docs/numbers.html#integer-types) | `Byte`, `Short`, `Int`, `Long` | `val year: Int = 2020`<br>`val amount: Long = 350_000_000` |
// | [Unsigned integers](https://kotlinlang.org/docs/unsigned-integer-types.html) | `UByte`, `UShort`, `UInt`, `ULong` | `val score: UInt = 100u` |
// | [Floating-point numbers](https://kotlinlang.org/docs/numbers.html#floating-point-types) | `Float`, `Double` | `val currentTemp: Float = 24.5f`<br>`val price: Double = 19.99` |
// | [Booleans](https://kotlinlang.org/docs/booleans.html) | `Boolean` | `val isEnabled: Boolean = true` |
// | [Characters](https://kotlinlang.org/docs/characters.html) | `Char` | `val separator: Char = ','` |
// | [Strings](https://kotlinlang.org/docs/strings.html) | `String` | `val message: String = "Hello, world!"` |

// %% [markdown]
// With this knowledge, you can declare variables and initialize them later. Kotlin can manage this as long as variables are initialized before the first read.
//
// To declare a variable without initializing it, specify its type with :. For example:

// %%
fun main() {
    // Variable declared without initialization
    val d: Int
    // Variable initialized
    d = 3

    // Variable explicitly typed and initialized
    val e: String = "hello"

    // Variables can be read because they have been initialized
    println(d) // 3
    println(e) // hello
}

main()
// Out:
// 3
// hello

// %% [markdown]
// > It is important to note that If you don't initialize a variable before it is read, you see an error:

// %%
fun main() {
    // Variable declared without initialization
    val d: Int

    // Triggers an error
    println(d)
    // Variable 'd' must be initialized
}
main()
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[17], line 6, column 13: Variable 'd' must be initialized
// 	at org.jetbrains.kotlinx.jupyter.compiler.CompiledScriptCache.deserializeResult-wUyqLnw(CompiledScriptCache.kt:36)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.internalEvaluator$lambda$0(ReplForJupyterImpl.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:129)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:729)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:93)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)
// ...

// %% [markdown]
// ## Collections
//
// When programming, it is useful to be able to group data into structures for later processing. Kotlin provides collections for exactly this purpose.

// %% [markdown]
// | Collection type | Description |
// |---|---|
// | Lists | Ordered collections of items |
// | Sets | Unique, unordered collections of items |
// | Maps | Collections of key-value pairs where each key is unique and maps to one value |

// %% [markdown]
// **Each collection type can be mutable or read only.**

// %% [markdown]
// ### [List](https://kotlinlang.org/docs/kotlin-tour-collections.html#list)

// %% [markdown]
// Lists store items in the order that they are added, and allow for duplicate items.
//
// To create a read-only list ([List]((https://kotlinlang.org/docs/kotlin-tour-collections.html#list))), use the [`listOf()`](https://kotlinlang.org/api/core/kotlin-stdlib/kotlin.collections/list-of.html) function.
//
// To create a mutable list ([MutableList](https://kotlinlang.org/api/core/kotlin-stdlib/kotlin.collections/-mutable-list.html)), use the [`mutableListOf()`](https://kotlinlang.org/api/core/kotlin-stdlib/kotlin.collections/mutable-list-of.html) function.

// %% [markdown]
// When creating lists, Kotlin can infer the type of items stored. To declare the type explicitly, add the type within angled brackets `<>` after the list declaration:

// %%
// Read only list
val readOnlyShapes = listOf("triangle", "square", "circle")
println(readOnlyShapes)
// [triangle, square, circle]

// Mutable list with explicit type declaration
val shapes: MutableList<String> = mutableListOf("triangle", "square", "circle")
println(shapes)
// [triangle, square, circle]
// Out:
// [triangle, square, circle]
// [triangle, square, circle]

// %% [markdown]
// >> To prevent unwanted modifications, you can create a read-only view of a mutable list by assigning it to a List:

// %%
val shapes: MutableList<String> = mutableListOf("triangle", "square", "circle")
val shapesLocked: List<String> = shapes

// %% [markdown]
// This is also called **casting**.

// %% [markdown]
// Lists are ordered so to access an item in a list, use the indexed access operator `[]`:

// %%
val readOnlyShapes = listOf("triangle", "square", "circle")
println("The first item in the list is: ${readOnlyShapes[2]}")
// The first item in the list is: triangle
// Out:
// The first item in the list is: circle

// %% [markdown]
// To get the first or last item in a list, use `.first()` and `.last()` functions respectively:

// %%
val readOnlyShapes = listOf("triangle", "square", "circle")
println("The first item in the list is: ${readOnlyShapes.first()}")
// The first item in the list is: triangle
// Out:
// The first item in the list is: triangle

// %%
println("The first item in the list is: ${readOnlyShapes.last()}")
// Out:
// The first item in the list is: circle

// %% [markdown]
// To get the number of items in a list, use the `.count()` function:

// %%
val readOnlyShapes = listOf("triangle", "square", "circle")
println("This list has ${readOnlyShapes.count()} items")
// This list has 3 items
// Out:
// This list has 3 items

// %% [markdown]
// To check that an item is in a list, use the `in` operator:

// %%
val readOnlyShapes = listOf("triangle", "square", "circle")
println("circle" in readOnlyShapes)
// true
// Out:
// true

// %% [markdown]
// To add or remove items from a mutable list, use `.add()` and `.remove()` functions respectively:

// %%
val shapes: MutableList<String> = mutableListOf("triangle", "square", "circle")
// Add "pentagon" to the list
shapes.add("pentagon")
println(shapes)
// [triangle, square, circle, pentagon]

// Remove the first "pentagon" from the list
shapes.remove("pentagon")
println(shapes)
// [triangle, square, circle]
// Out:
// [triangle, square, circle, pentagon]
// [triangle, square, circle]

// %% [markdown]
// ### [Set](https://kotlinlang.org/docs/kotlin-tour-collections.html#set)
//
// Whereas lists are ordered and allow duplicate items, sets are **unordered** and only store unique items.
//
// - To create a read-only set (`Set`), use the `setOf()` function.
//
// - To create a mutable set (`MutableSet`), use the `mutableSetOf()` function.
//
// When creating sets, Kotlin can infer the type of items stored. To declare the type explicitly, add the type within angled brackets `<>` after the set declaration:

// %%
// Read-only set
val readOnlyFruit = setOf("apple", "banana", "cherry", "cherry")

// %%
// Read-only set
val readOnlyFruit = setOf<String>("apple", "banana", "cherry", "cherry")

// %%
// Mutable set with explicit type declaration
val fruit: MutableSet<String> = mutableSetOf("apple", "banana", "cherry", "cherry")

println(readOnlyFruit)
// [apple, banana, cherry]
// Out:
// [apple, banana, cherry]

// %% [markdown]
// > You can see in the previous example that because sets only contain unique elements, the duplicate "cherry" item is dropped.

// %% [markdown]
// To prevent unwanted modifications, you can create a read-only view of a mutable set by assigning it to a Set:

// %%
val fruit: MutableSet<String> = mutableSetOf("apple", "banana", "cherry", "cherry")
val fruitLocked: Set<String> = fruit

// %%
val readOnlyFruit = setOf("apple", "banana", "cherry", "cherry")
println("This set has ${readOnlyFruit.count()} items")
// This set has 3 items
// Out:
// This set has 3 items

// %% [markdown]
// To check that an item is in a set, use the in operator:

// %%
val readOnlyFruit = setOf("apple", "banana", "cherry", "cherry")
println("banana" in readOnlyFruit)
// true
// Out:
// true

// %% [markdown]
// To add or remove items from a mutable set, use .add() and .remove() functions respectively:

// %%
val fruit: MutableSet<String> = mutableSetOf("apple", "banana", "cherry", "cherry")
fruit.add("dragonfruit")    // Add "dragonfruit" to the set
println(fruit)              // [apple, banana, cherry, dragonfruit]

fruit.remove("dragonfruit") // Remove "dragonfruit" from the set
println(fruit)              // [apple, banana, cherry]
// Out:
// [apple, banana, cherry, dragonfruit]
// [apple, banana, cherry]

// %% [markdown]
// ### [Map](https://kotlinlang.org/docs/kotlin-tour-collections.html#map)
// Maps store items as key-value pairs.
//
// - To create a read-only map (`Map`), use the `mapOf()` function.
//
// - To create a mutable map (`MutableMap`), use the `mutableMapOf()` function.
//
// To declare the type explicitly, add the types of the keys and values within angled brackets `<>` after the map declaration.

// %% [markdown]
// The easiest way to create maps is `to` use to between each key and its related value:

// %%
// Read-only map
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println(readOnlyJuiceMenu)
// {apple=100, kiwi=190, orange=100}

// Mutable map with explicit type declaration
val juiceMenu: MutableMap<String, Int> = mutableMapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println(juiceMenu)
// {apple=100, kiwi=190, orange=100}
// Out:
// {apple=100, kiwi=190, orange=100}
// {apple=100, kiwi=190, orange=100}

// %% [markdown]
// If you try to access a key-value pair with a key that doesn't exist in a map, you see a null value:

// %%
// Read-only map
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println("The value of pineapple juice is: ${readOnlyJuiceMenu["pineapple"]}")
// The value of pineapple juice is: null
// Out:
// The value of pineapple juice is: null

// %% [markdown]
// You can also use the indexed access operator [] to add items to a mutable map:

// %%
val juiceMenu: MutableMap<String, Int> = mutableMapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
juiceMenu["coconut"] = 150 // Add key "coconut" with value 150 to the map
println(juiceMenu)
// {apple=100, kiwi=190, orange=100, coconut=150}
// Out:
// {apple=100, kiwi=190, orange=100, coconut=150}

// %% [markdown]
// To remove items from a mutable map, use the `.remove()` function:

// %%
val juiceMenu: MutableMap<String, Int> = mutableMapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
juiceMenu.remove("orange")    // Remove key "orange" from the map
println(juiceMenu)
// {apple=100, kiwi=190}
// Out:
// {apple=100, kiwi=190}

// %%
juiceMenu.remove("o")    // Remove key "orange" from the map
// Out:
// null

// %% [markdown]
// To get the number of items in a map, use the .count() function:

// %%
// Read-only map
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println("This map has ${readOnlyJuiceMenu.count()} key-value pairs")
// This map has 3 key-value pairs
// Out:
// This map has 3 key-value pairs

// %%
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println(readOnlyJuiceMenu.containsKey("kiwi"))
// true
// Out:
// true

// %% [markdown]
// To obtain a collection of the keys or values of a map, use the keys and values properties respectively:

// %%
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println(readOnlyJuiceMenu.keys)
// [apple, kiwi, orange]
println(readOnlyJuiceMenu.values)
// [100, 190, 100]
// Out:
// [apple, kiwi, orange]
// [100, 190, 100]

// %%
val readOnlyJuiceMenu = mapOf("apple" to 100, "kiwi" to 190, "orange" to 100)
println("orange" in readOnlyJuiceMenu.keys)
// true

// Alternatively, you don't need to use the keys property
println("orange" in readOnlyJuiceMenu)
// true

println(200 in readOnlyJuiceMenu.values)
// false
// Out:
// true
// true
// false

// %% [markdown]
// ## Control flow
//
// - Kotlin can make decisions based on whether an expression evaluates to `true` or `false`
// - These are called **conditional expressions**
// - Conditionals allow programs to choose different execution paths
//
// ### Kotlin supports:
// - **Conditional expressions**
//   - `if`, `when`
// - **Loops**
//   - `for`
//   - `while`
//   - `do-while`
//
// ### Purpose
// - Enable decision-making in programs
// - Allow repetition of actions
// - Form the foundation of program logic and flow control

// %% [markdown]
// ### Conditional expressions
//
// Kotlin provides `if` and `when` for checking conditional expressions.
//
// > **Recommendation:**
// > When both `if` and `when` are valid options, **use `when` for better readability and structure**.

// %% [markdown]
// ### If
//
// To use `if`, place the condition inside parentheses `()`
// and the action inside curly braces `{}`:

// %%
fun main() {
    val d: Int
    val check = true

    if (check) {
        d = 1
    } else {
        d = 2
    }

    println(d)
    // 1
}
// 1
main()
// Out:
// 1

// %% [markdown]
//  If there is only one line of code per action, the curly braces `{}` are optional:

// %%
val a = 1
val b = 2

println(if (a > b) a else b) // Returns a value: 2
// Out:
// 2

// %% [markdown]
// ### When
//
// Use `when` when you have a **conditional expression with multiple branches**.
//
// ### Syntax Rules
// - Place the value to evaluate inside parentheses `()`
// - Place all branches inside curly braces `{}`
// - Use `->` to separate:
//   - the condition (check)
//   - the action (result or code)
//
// ### Structure
// ```kotlin
// when (value) {
//     condition1 -> action1
//     condition2 -> action2
//     else -> defaultAction
// }

// %% [markdown]
// when can be used either as a statement or as an expression. A statement doesn't return anything but performs actions instead.
// Here is an example of using `when` as a statement:

// %%
fun main() {
    val obj = "Hello"

    when (obj) {
        // Checks whether obj equals to "1"
        "1" -> println("One")
        // Checks whether obj equals to "Hello"
        "Hello" -> println("Greeting")
        // Default statement
        else -> println("Unknown")
    }
    // Greeting
}
main()
// Out:
// Greeting

// %% [markdown]
// An **expression** returns a value that can be used later in your code.

// %%
fun main() {

    val obj = "Hello"

    val result = when (obj) {
        // If obj equals "1", sets result to "one"
        "1" -> "One"
        // If obj equals "Hello", sets result to "Greeting"
        "Hello" -> "Greeting"
        // Sets result to "Unknown" if no previous condition is satisfied
        else -> "Unknown"
    }
    println(result)
    // Greeting
}

// %% [markdown]
// ## `when` Without a Subject in Kotlin
//
// So far, `when` examples have used a **subject** (e.g., `when(obj)`).
// However, Kotlin also allows `when` to be used **without a subject**.
//
// This form is useful for evaluating a **chain of Boolean expressions**.
//
// ### Syntax
// ```kotlin
// when {
//     condition1 -> action1
//     condition2 -> action2
//     condition3 -> action3
//     else -> defaultAction
// }

// %%
fun main() {
    val trafficLightState = "Red" // This can be "Green", "Yellow", or "Red"

    val trafficAction = when {
        trafficLightState == "Green" -> "Go"
        trafficLightState == "Yellow" -> "Slow down"
        trafficLightState == "Red" -> "Stop"
        else -> "Malfunction"
    }

    println(trafficAction)
    // Stop
}
main()
// Out:
// Stop

// %% [markdown]
// However, you can have the same code but with `trafficLightState` as the subject:

// %%
fun main() {
    val trafficLightState = "Red" // This can be "Green", "Yellow", or "Red"

    val trafficAction = when (trafficLightState) {
        "Green" -> "Go"
        "Yellow" -> "Slow down"
        "Red" -> "Stop"
        else -> "Malfunction"
    }

    println(trafficAction)
    // Stop
}

main()
// Out:
// Stop

// %% [markdown]
// > **Best Practice with `when`:**
// > Using `when` with a **subject** makes code **easier to read**, **easier to maintain**, and **safer**.
// >
// > - Kotlin can check that **all possible cases are covered**
// > - Improves correctness at compile time
// > - Reduces logical errors
// >
// > ⚠️ If `when` is used **without a subject**, you **must include an `else` branch**

// %% [markdown]
// ### Ranges
//
// Ranges are commonly used in loops to define the set of values to iterate over.
//
// ### Creating Ranges
//
// - **Inclusive range** (`..`)
//   - Includes the end value
//   - Example: `1..4` → `1, 2, 3, 4`

// %%
val r1 = 1..4
r1
// Values: 1, 2, 3, 4
// Out:
// 1..4

// %% [markdown]
// - **Exclusive end range** (`..<`)
//   - Excludes the end value
//   - Example: `1..<4` → `1, 2, 3`

// %%
val r2 = 1..<4
r2
// Values: 1, 2, 3
// Out:
// 1..3

// %% [markdown]
// - **Descending range** (`downTo`)
//   - Iterates in reverse order
//   - Example: `4 downTo 1` → `4, 3, 2, 1`

// %%
val r3 = 4 downTo 1
r3
// Values: 4, 3, 2, 1
// Out:
// 4 downTo 1 step 1

// %% [markdown]
// - **Step range** (`step`)
//   - Skips values by a fixed increment
//   - Example: `1..5 step 2` → `1, 3, 5`

// %%
val r4 = 1..5 step 2
r4
// Values: 1, 3, 5
// Out:
// 1..5 step 2

// %% [markdown]
// ### Character Ranges
//
// - `'a'..'d'` → `'a', 'b', 'c', 'd'`
// - `'z' downTo 's' step 2` → `'z', 'x', 'v', 't'

// %%
val letters1 = 'a'..'d'
// Values: a, b, c, d

letters1
// Out:
// a..d

// %%
val letters2 = 'z' downTo 's' step 2
letters2
// Values: z, x, v, t
// Out:
// z downTo t step 2

// %% [markdown]
// ### Why Ranges Matter
// - Clean loop construction
// - Readable iteration logic
// - Supports numeric and character sequences
// - Functional-style iteration support

// %% [markdown]
// ## Loops
// - The two most common loop structures in programming are:
//   - `for`
//   - `while`

// %% [markdown]
// #### For
// Using ranges, you can create a `for` loop that iterates over a sequence of values.
//
// ### Syntax
// Place the iterator and the range inside parentheses `()` using the keyword `in`.
// Place the action inside curly braces `{}`.

// %%
for (number in 1..5) {
    // number is the iterator and 1..5 is the range
    print(number)
}
// 12345
// Out:
// 12345

// %% [markdown]
// Collections can also be iterated over by loops:

// %%
val cakes = listOf("carrot", "cheese", "chocolate")

for (cake in cakes) {
    println("Yummy, it's a $cake cake!")
}
// Yummy, it's a carrot cake!
// Yummy, it's a cheese cake!
// Yummy, it's a chocolate cake!
// Out:
// Yummy, it's a carrot cake!
// Yummy, it's a cheese cake!
// Yummy, it's a chocolate cake!

// %% [markdown]
// #### `while`
//
// `while` loops can be used in two ways:
//
// - **`while` loop**
//   → Checks the condition **before** executing the code block
// - **`do-while` loop**
//   → Executes the code block **first**, then checks the condition
//
// ---

// %% [markdown]
// `while`:
//
// - Declare the conditional expresion for you while loop within `()`
// - Add the action you want to complete within culry braces `{}`
//
// Example:

// %%
var cakesEaten = 0
while (cakesEaten < 3) {
    println("Eat a cake")
    cakesEaten++
}
// Out:
// Eat a cake
// Eat a cake
// Eat a cake

// %% [markdown]
// `do-while` :
// - Declare the conditional expression for your while loop to continue within `()`.
// - Define the action you want to complete within curly braces {} with the keyword `do`
//
// Example:

// %%
var cakesEaten = 0
var cakesBaked = 0
while (cakesEaten < 3) {
    println("Eat a cake")
    cakesEaten++
}

do {
    println("Bake a cake")
    cakesBaked++
} while (cakesBaked < cakesEaten)
// Out:
// Eat a cake
// Eat a cake
// Eat a cake
// Bake a cake
// Bake a cake
// Bake a cake

// %%
// Out:
// 3
// 3

// %% [markdown]
// ## References
// -  Chapter 2. Kotlin basics. Aigner, Sebastian, et al. Kotlin in action. Simon and Schuster, 2024.
// - Kotlin Foundation. “Kotlin Tour.”  Accessed 15 Jan. 2026.

// %% [markdown]
// ## Funcitons
// The purpose of a function is to compute and return a result. For example, we can write a simple function max that takes two integers, a and b, and returns the larger one.
//
// In Kotlin:
//
// A function is declared using the keyword fun, followed by the function name (e.g., max).
// The parameter list is defined inside parentheses ().
// Each parameter is written as name first, then type, separated by a colon (:).

// %%
fun max(a: Int, b: Int) : Int {
    return if (a > b) a else b
}

// %% [markdown]
// In the following example:
//
// - `a` and `b` are function parameters.
// - Both parameters have the type `Int`.
// - The function's return type is `Int`.
// - The function compares `a` and `b`.
// - It returns `a` if `a` is greater than `b`; otherwise, it returns `b`.

// %%
println(max(1, 2))
// Out:
// 2

// %% [markdown]
// ### Named arguments
// For concise code, when calling your function, you don't have to include parameter names. However, If you do include parameter names, then you can write the parameters in any order.

// %%
fun max(a: Int, b: Int) : Int {
    return if (a > b) a else b
}

print(max(b=10, a=100))
// Out:
// 100

// %% [markdown]
// ### Default parameter values
// You can define default values for your function parameters. Any parameter with a default value can be omitted when calling your function

// %%
fun printMessageWithPrefix(message: String, prefix: String = "Info") {
    println("[$prefix] $message")
}

fun main() {
    // Function called with both parameters
    printMessageWithPrefix("Hello", "Log")
    // [Log] Hello

    // Function called only with message parameter
    printMessageWithPrefix("Hello")
    // [Info] Hello

    printMessageWithPrefix(prefix = "Log", message = "Hello")
    // [Log] Hello
}

main()
// Out:
// [Log] Hello
// [Info] Hello
// [Log] Hello

// %% [markdown]
// ### Functions without return
//
// If your function doesn't return a useful value, then its return type is `Unit`.

// %%
fun printMessage(message: String) {
    println(message)
    // `return Unit` or `return` is optional
}

fun main() {
    printMessage("Hello")
    // Hello
}

// %% [markdown]
// ### Single-expression functions
// To make your code more concise, you can use single-expression functions. For example, the `sum()` function can be shortened:

// %%
fun sum(x: Int, y: Int): Int {
    return x + y
}

fun main() {
    println(sum(1, 2))
    // 3
}

main()
// Out:
// 3

// %% [markdown]
// You can remove the curly braces {} and declare the function body using the assignment operator =. When you use the assignment operator =, Kotlin uses type inference, so you can also omit the return type. The sum() function then becomes one line:

// %%
fun sum(x: Int, y: Int) = x + y

fun main() {
    println(sum(1, 2))
    // 3
}

main()
// Out:
// 3

// %% [markdown]
// ### Early returns in functions
//
// To stop the code in your function from being processed further than a certain point, use the return keyword. This example uses if to return from a function early if the conditional expression is found to be true:

// %% [markdown]
// # When in doubt

// %%
// A list of registered usernames
val registeredUsernames = mutableListOf("john_doe", "jane_smith")

// A list of registered emails
val registeredEmails = mutableListOf("john@example.com", "jane@example.com")

fun registerUser(username: String, email: String): String {
    // Early return if the username is already taken
    if (username in registeredUsernames) {
        return "Username already taken. Please choose a different username."
    }

    // Early return if the email is already registered
    if (email in registeredEmails) {
        return "Email already registered. Please use a different email."
    }

    // Proceed with the registration if the username and email are not taken
    registeredUsernames.add(username)
    registeredEmails.add(email)

    return "User registered successfully: $username"
}

fun main() {
    println(registerUser("john_doe", "newjohn@example.com"))
    // Username already taken. Please choose a different username.
    println(registerUser("new_user", "newuser@example.com"))
    // User registered successfully: new_user
}

main()
// Out:
// Username already taken. Please choose a different username.
// User registered successfully: new_user

// %% [markdown]
// ## When in doubt
//
// - [kotlinlang.org](kotlinlang.org)
// - [kotlinlang.org/docs](kotlinlang.org/docs)
// - [play.kotlinlang.org/byExample](play.kotlinlang.org/byExample)
