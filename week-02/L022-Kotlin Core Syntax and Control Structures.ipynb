// %% [markdown]
// # 2.1 - Kotlin Core Syntax and Control Structures

// %% [markdown]
// * Kotlin is a modern programming language that runs on the Java Virtual Machine (JVM) and beyond.
// * It is a general-purpose, concise, safe, and pragmatic language.
// * It is used to build mobile, server-side, and desktop applications, among many others.

// %%
data class Person(            // Data class
    val name: String,        // Read-only property
    val age: Int? = null     // Nullable type (Int?) - the default value for the argument
)

fun main(){                 //Top-level function
    val persons = listOf(
        Person("Alice", age = 29), //Name argument
        Person("Bob"),  // Trailing comma
    )

    val  oldest = persons.maxBy { // Lambda expression
        it.age ?: 0               // Null-coalescing Elvis operator
    }
    println("The oldest is: $oldest")  // string template
}
main()
// Out:
// The oldest is: Person(name=Alice, age=29)

// %% [markdown]
// Our first Kotlin code snippet demonstrates how to create a collection in Kotlin, populate it with `Person` objects, and then find the oldest person in the collection, using default values when no `age` is specified.
//
// * When creating the list of people, Bob’s age is omitted, so `null` is used as the default value.
// * To find the oldest person in the list, the `maxBy` function is used.
// * The lambda expression passed to the function takes one parameter, implicitly named `it` by default (although you can assign other name if desired).
// * The Elvis operator (`?:`) returns `0` if `age` is `null`. Because Bob’s age isn’t specified, it defaults to `0` during the comparison.

// %% [markdown]
// ## Kotlin's Primary Traits
//
// - Kotlin is a **multi-paradigm** language.
// - It is **statically typed**, meaning many errors can be caught at compile time instead of at runtime.
// - It combines ideas from **object-oriented (OO)** and **functional** programming, helping you write elegant code and use powerful abstractions.
// - It provides strong support for **asynchronous programming**, which is essential in many modern development domains.

// %% [markdown]
// ### Kotlin Use Cases
//
// Common Kotlin use cases include the following:
//
// - Building mobile applications that run on Android devices
// - Developing server-side systems (e.g., backends for web applications)

// %% [markdown]
// ### Static Typing
//
// Kotlin is **statically typed**, meaning many errors can be caught at compile time instead of at runtime. The main advantages include:
//
// - **Performance**: Method calls are faster.
// - **Reliability**: The compiler uses types to verify program consistency, reducing the chance of runtime crashes.
// - **Maintainability**: Working with unfamiliar code is easier because types make the structure and intent clearer.
// - **Tool support**: Enables reliable refactoring, precise code completion, and advanced IDE features.
//
// In contrast, **dynamically typed** languages such as Python or JavaScript allow variables and functions to store or return values of any type, resolving method and field references at runtime. The disadvantage is that issues like misspelled names or invalid parameters cannot be detected during compilation and may lead to runtime errors.
//
// > **Important:** Kotlin does not require explicit type declarations for every variable. In many cases, the type is automatically inferred from the context, allowing you to omit the type while still benefiting from static typing.

// %%
val x: Int = 1 // You can specify the variable type explicitly.
val y  = 1 // But often, you don't have specify it.
println(x and y)

// %% [markdown]
// ### Final Goal: Combining Functional and Object-Oriented Programming
//
// As a multiparadigm programming language. Kotlin combines *object-oriented* approach with the *functional programming style*

// %% [markdown]
// ##  Basic elements: Functions and variables

// %% [markdown]
// ### Hello, World!

// %%
fun main() {
    println("Hello, World!")
}

main()
// Out:
// Hello, World!

// %% [markdown]
// In Kotlin:
//
// - `fun` is used to **declare** a function.
// - The `main()` function is where your program **starts execution**.
//   - Just like in other programming languages such as Java, the entry point of a Kotlin application is the `main` function.
//   - This function can accept a variable number of `String` arguments, but these arguments can be omitted when they are not needed.
// - The body of a function is written within **curly braces** `{}`.
// - Kotlin allows you to **omit semicolons** at the end of lines.

// %%
fun main(args: Array<String>) {
    println("Hello, world!")
}
main()
// Out:
// Hello, world!

// %%
fun main() = println("Hello, world!")
main()
// Out:
// Hello, world!

// %% [markdown]
// ## Declaring Functions
//
// The purpose of a function is to compute and return a result. For example, we can write a simple function `max` that takes two integers, `a` and `b`, and returns the larger one.
//
// In Kotlin:
//
// - A function is declared using the keyword `fun`, followed by the function name (e.g., `max`).
// - The parameter list is defined inside parentheses `()`.
//   - Each parameter is written as **name first, then type**, separated by a colon (`:`).

// %%
fun max(a: Int, b: Int) : Int {
    return if (a > b) a else b
}

// %% [markdown]
// You can then call your function by using its name, providing the arguments in `()`

// %%
println(max(1, 2))
// Out:
// 2

// %%
fun sum(a: Int, b: Int): Int {
    return a + b
}

println(sum(1, 2))
// Out:
// 3

// %% [markdown]
// The above functions are examples of function definitions with parameters and return values. As you already saw in the “Hello, World!” example, the `main` function does not return a value.
//
// `Unit` is the actual return type used by Kotlin for functions that return no meaningful value (similar to `void` in Java).

// %%
fun printMul(a: Int, b: Int) {
    println("${a*b}")
}

printMul(2, 3)
// Out:
// 6

// %% [markdown]
// Here, the return type is omitted, but the function's actual return type is `Unit`. This is equivalent to:

// %%
fun printMul(a: Int, b: Int): Unit {
    println("${a*b}")
}

printMul(2, 3)
// Out:
// 6

// %% [markdown]
// ## Expressions vs. Statements in Kotlin
//
// - An **expression** has a value and can be used inside other expressions.
// - A **statement** does not produce a value and exists only as a top-level instruction.
//
// > In Kotlin, most control structures are expressions (except loops: `for`, `while`, `do/while`).
//
// The ability to combine control structures with other expressions allows Kotlin to express many common patterns **concisely and clearly**.
// As a preview, here are some examples of valid Kotlin expressions:

// %%
enum class Direction { UP, DOWN, UNKNOWN }
// Define variables
val myBoolean = true
val inputString = "u"

// Expression examples
val x = if (myBoolean) 3 else 5

val direction = when (inputString) {
    "u" -> Direction.UP
    "d" -> Direction.DOWN
    else -> Direction.UNKNOWN
}
// Output
println(x)
println(direction)
// Out:
// 3
// UP

// %% [markdown]
// ## Making function definitions more concise by using expression bodies
//
// When a function consists of a **single expression**, Kotlin allows you to make it more concise by:
// - Removing the curly braces `{}`
// - Removing the `return` statement
// - Placing the expression directly after an equals sign (`=`)
//
// This creates an **expression body** function.

// %% [markdown]
// ### Block Body vs Expression Body in Kotlin

// %% [markdown]
// **Standard (block body) function:**
// ```kotlin
// fun max(a: Int, b: Int): Int {
//     return if (a > b) a else b
// }
// ```
//
//
// **Expression body function:**

// %%
fun max(a: Int, b: Int): Int = if (a > b) a else b

max(2, 3)
// Out:
// 3

// %% [markdown]
// In summary:
// - Block body → uses `{}` and `return`
//
// - Expression body → single expression after `=`, no braces, no return

// %% [markdown]
// You could simplify your `max` function even more and omit the return type:

// %%
fun max(a: Int, b: Int) = if (a > b) a else b
max(2, 3)
// Out:
// 3

// %% [markdown]
// > **Important:**
// By explicitly specifying the types of your functions, you can prevent accidental signature changes that could introduce errors in the code of your library’s consumers.

// %% [markdown]
// ### Variables in Kotlin
//
// Kotlin uses two keywords to control whether a variable can be reassigned:
//
// - **`val`** → *read-only reference*
//   Assigned once and cannot be reassigned (similar to `final` in Java).
//
// - **`var`** → *reassignable reference (mutable)*
//   Can be reassigned after initialization (like a regular non-`final` variable in Java).
//
// > Use `val` by default, and `var` only when mutation is necessary.

// %% [markdown]
// > **Important:**
// A `val` variable must be initialized **exactly once** within its scope.
// However, it may be initialized conditionally, as long as the compiler can guarantee that **only one initialization path** will execute.

// %% [markdown]
// **Summary:**
// You can use `val` for variables that are **conditionally initialized**, as long as the compiler can guarantee that **exactly one assignment** will occur at runtime—even when the value depends on another function’s result.

// %%
fun canPerformOperation(): Boolean {
    return false
}

fun main() {
    val result: String
    if (canPerformOperation()) {
        result = "Success"
    } else {
        result = "Can't perform operation"
    }
    println(result)
}

main()
// Out:
// Can't perform operation

// %%
val popcorn = 5    // There are 5 boxes of popcorn
val hotdog = 7     // There are 7 hotdogs
var customers = 10 // There are 10 customers in the queue

// Some customers leave the queue
customers = 8
println(customers)
// 8
// Out:
// 8

// %% [markdown]
// As `customers` is a mutable variable, its value can be reassigned after declaration.

// %% [markdown]
// ## String templates
//
// Kotlin uses **string templates** to easily print variables and expressions to standard output.
//
// - Strings are written inside double quotes `" "`
// - Template expressions start with a dollar sign `$`
// - Variables can be embedded directly in strings
// - Expressions must be wrapped in `{}`

// %%
val customers = 10
println("There are $customers customers")
// There are 10 customers

println("There are ${customers + 1} customers")
// There are 11 customers
// Out:
// There are 10 customers
// There are 11 customers

// %% [markdown]
// ## Basic types
//
// - Every variable and data structure in Kotlin has a **type**
// - Types define:
//   - What operations are allowed
//   - What functions and properties are available
// - The compiler uses types to enforce **correct usage** of variables
//
// ### Type Inference
// - Kotlin can automatically determine a variable’s type
// - This is called **type inference**

// %%
var customers = 10

// Some customers leave the queue
customers = 8

customers = customers + 3 // Example of addition: 11
customers += 7            // Example of addition: 18
customers -= 3            // Example of subtraction: 15
customers *= 2            // Example of multiplication: 30
customers /= 3            // Example of division: 10

println(customers) // 10
// Out:
// 10

// %% [markdown]
// In this example, `customers` is assigned an integer value. Kotlin infers its type as `Int`

// %% [markdown]
// ## Basic Types in Kotlin
//
// | Category              | Basic Types                    | Example Code                                  |
// |-----------------------|--------------------------------|-----------------------------------------------|
// | Integers               | `Byte`, `Short`, `Int`, `Long`  | `val year: Int = 2020`                         |
// | Unsigned Integers      | `UByte`, `UShort`, `UInt`, `ULong` | `val score: UInt = 100u`                    |
// | Floating-point Numbers | `Float`, `Double`              | `val currentTemp: Float = 24.5f`<br>`val price: Double = 19.99` |
// | Booleans               | `Boolean`                      | `val isEnabled: Boolean = true`               |
// | Characters             | `Char`                         | `val separator: Char = ','`                   |
// | Strings                | `String`                       | `val message: String = "Hello, world!"`       |

// %% [markdown]
// For more information on basic types and their properties, see [Types overview](https://kotlinlang.org/docs/types-overview.html).

// %% [markdown]
// - If a variable is **assigned immediately**, Kotlin uses **type inference**
// - If a variable has **no initial value**, the **type must be explicitly declared**

// %%
fun main() {
    // Variable declared without initialization
    val d: Int
    // Variable initialized
    d = 3

    // Variable explicitly typed and initialized
    val e: String = "hello"

    // Variables can be read because they have been initialized
    println(d) // 3
    println(e) // hello
}
main()
// Out:
// 3
// hello

// %% [markdown]
// If you don't initialize a variable before it is read, you see an error:

// %%
fun main() {
    // Variable declared without initialization
    val d: Int

    // Triggers an error
    println(d)
    // Variable 'd' must be initialized
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[15], line 6, column 13: Variable 'd' must be initialized
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:730)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:93)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:591)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:472)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx$lambda$0(ReplForJupyterImpl.kt:466)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:448)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:465)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0$0(IdeCompatibleMessageRequestProcessor.kt:161)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:351)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:364)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:341)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0(IdeCompatibleMessageRequestProcessor.kt:363)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:334)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:362)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:160)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl.executorThread$lambda$0(JupyterExecutorImpl.kt:81)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// ## Control flow
//
// - Kotlin can make decisions based on whether an expression evaluates to `true` or `false`
// - These are called **conditional expressions**
// - Conditionals allow programs to choose different execution paths
//
// ### Kotlin supports:
// - **Conditional expressions**
//   - `if`, `when`
// - **Loops**
//   - `for`
//   - `while`
//   - `do-while`
//
// ### Purpose
// - Enable decision-making in programs
// - Allow repetition of actions
// - Form the foundation of program logic and flow control

// %% [markdown]
// ### Conditional expressions
//
// Kotlin provides `if` and `when` for checking conditional expressions.
//
// > **Recommendation:**
// > When both `if` and `when` are valid options, **use `when` for better readability and structure**.

// %% [markdown]
// ### If
//
// To use `if`, place the condition inside parentheses `()`
// and the action inside curly braces `{}`:

// %%
fun main() {
    val d: Int
    val check = true

    if (check) {
        d = 1
    } else {
        d = 2
    }

    println(d)
    // 1
}
// 1
main()
// Out:
// 1

// %% [markdown]
// ### `if` as an Expression in Kotlin
//
// - In Kotlin, `if` can be used as an **expression** (it returns a value)
// - The result of an `if` expression can be assigned to a variable
// - If there is **only one line of code per branch**, curly braces `{}` are **optional**

// %%
val a = 1
val b = 2

println(if (a > b) a else b) // Returns a value: 2
// Out:
// 2

// %% [markdown]
// ### When
//
// Use `when` when you have a **conditional expression with multiple branches**.
//
// ### Syntax Rules
// - Place the value to evaluate inside parentheses `()`
// - Place all branches inside curly braces `{}`
// - Use `->` to separate:
//   - the condition (check)
//   - the action (result or code)
//
// ### Structure
// ```kotlin
// when (value) {
//     condition1 -> action1
//     condition2 -> action2
//     else -> defaultAction
// }

// %% [markdown]
// when can be used either as a statement or as an expression. A statement doesn't return anything but performs actions instead.
// Here is an example of using `when` as a statement:

// %%
fun main() {
    val obj = "Hello"

    when (obj) {
        // Checks whether obj equals to "1"
        "1" -> println("One")
        // Checks whether obj equals to "Hello"
        "Hello" -> println("Greeting")
        // Default statement
        else -> println("Unknown")
    }
    // Greeting
}
main()
// Out:
// Greeting

// %% [markdown]
// An **expression** returns a value that can be used later in your code.

// %%
fun main() {

    val obj = "Hello"

    val result = when (obj) {
        // If obj equals "1", sets result to "one"
        "1" -> "One"
        // If obj equals "Hello", sets result to "Greeting"
        "Hello" -> "Greeting"
        // Sets result to "Unknown" if no previous condition is satisfied
        else -> "Unknown"
    }
    println(result)
    // Greeting
}

// %% [markdown]
// ## `when` Without a Subject in Kotlin
//
// So far, `when` examples have used a **subject** (e.g., `when(obj)`).
// However, Kotlin also allows `when` to be used **without a subject**.
//
// This form is useful for evaluating a **chain of Boolean expressions**.
//
// ### Syntax
// ```kotlin
// when {
//     condition1 -> action1
//     condition2 -> action2
//     condition3 -> action3
//     else -> defaultAction
// }

// %%
fun main() {
    val trafficLightState = "Red" // This can be "Green", "Yellow", or "Red"

    val trafficAction = when {
        trafficLightState == "Green" -> "Go"
        trafficLightState == "Yellow" -> "Slow down"
        trafficLightState == "Red" -> "Stop"
        else -> "Malfunction"
    }

    println(trafficAction)
    // Stop
}
main()
// Out:
// Stop

// %% [markdown]
// However, you can have the same code but with `trafficLightState` as the subject:

// %%
fun main() {
    val trafficLightState = "Red" // This can be "Green", "Yellow", or "Red"

    val trafficAction = when (trafficLightState) {
        "Green" -> "Go"
        "Yellow" -> "Slow down"
        "Red" -> "Stop"
        else -> "Malfunction"
    }

    println(trafficAction)
    // Stop
}

main()
// Out:
// Stop

// %% [markdown]
// > ⭐ **Best Practice with `when`:**
// > Using `when` with a **subject** makes code **easier to read**, **easier to maintain**, and **safer**.
// >
// > - Kotlin can check that **all possible cases are covered**
// > - Improves correctness at compile time
// > - Reduces logical errors
// >
// > ⚠️ If `when` is used **without a subject**, you **must include an `else` branch**

// %% [markdown]
// #### P1: In-Class Exercise — Kotlin Expressions & Control Structures
// Kotlin
// ```
// fun classifyScore(score: Double): String {
//     var grade = ""
//
//     if (score >= 95) {
//         grade = "A"
//     } else if (score >= 90) {
//         grade = "A-"
//     } else if (score >= 87) {
//         grade = "B+"
//     } else if (score >= 83) {
//         grade = "B"
//     } else if (score >= 80) {
//         grade = "B-"
//     } else if (score >= 77) {
//         grade = "C+"
//     } else if (score >= 73) {
//         grade = "C"
//     } else if (score >= 70) {
//         grade = "C-"
//     } else if (score >= 67) {
//         grade = "D+"
//     } else if (score >= 63) {
//         grade = "D"
//     } else if (score >= 60) {
//         grade = "D-"
//     } else {
//         grade = "F"
//     }
//
//     return grade
// }
// ```

// %% [markdown]
// #### Solution P1
//
// Here are two Kotlin refactors using `when`:
// With subject:

// %%
fun classifyScore(score: Double): String =
    when (score) {
        in 95.0..100.0 -> "A"
        in 90.0..<95.0 -> "A-"
        in 87.0..<90.0 -> "B+"
        in 83.0..<87.0 -> "B"
        in 80.0..<83.0 -> "B-"
        in 77.0..<80.0 -> "C+"
        in 73.0..<77.0 -> "C"
        in 70.0..<73.0 -> "C-"
        in 67.0..<70.0 -> "D+"
        in 63.0..<67.0 -> "D"
        in 60.0..<63.0 -> "D-"
        else -> "F"
    }

classifyScore(73.0)
// Out:
// C

// %% [markdown]
// Without subject:

// %%
fun classifyScore(score: Double): String =
    when {
        score >= 95 -> "A"
        score >= 90 -> "A-"
        score >= 87 -> "B+"
        score >= 83 -> "B"
        score >= 80 -> "B-"
        score >= 77 -> "C+"
        score >= 73 -> "C"
        score >= 70 -> "C-"
        score >= 67 -> "D+"
        score >= 63 -> "D"
        score >= 60 -> "D-"
        else -> "F"
    }
classifyScore(73.0)
// Out:
// C

// %% [markdown]
// ### Ranges
//
// Ranges are commonly used in loops to define the set of values to iterate over.
//
// ### Creating Ranges
//
// - **Inclusive range** (`..`)
//   - Includes the end value
//   - Example: `1..4` → `1, 2, 3, 4`

// %%
val r1 = 1..4
r1
// Values: 1, 2, 3, 4
// Out:
// 1..4

// %% [markdown]
// - **Exclusive end range** (`..<`)
//   - Excludes the end value
//   - Example: `1..<4` → `1, 2, 3`

// %%
val r2 = 1..<4
r2
// Values: 1, 2, 3
// Out:
// 1..3

// %% [markdown]
// - **Descending range** (`downTo`)
//   - Iterates in reverse order
//   - Example: `4 downTo 1` → `4, 3, 2, 1`

// %%
val r3 = 4 downTo 1
r3
// Values: 4, 3, 2, 1
// Out:
// 4 downTo 1 step 1

// %% [markdown]
// - **Step range** (`step`)
//   - Skips values by a fixed increment
//   - Example: `1..5 step 2` → `1, 3, 5`

// %%
val r4 = 1..5 step 2
r4
// Values: 1, 3, 5
// Out:
// 1..5 step 2

// %% [markdown]
// ### Character Ranges
//
// - `'a'..'d'` → `'a', 'b', 'c', 'd'`
// - `'z' downTo 's' step 2` → `'z', 'x', 'v', 't'`

// %%
val letters1 = 'a'..'d'
// Values: a, b, c, d

letters1
// Out:
// a..d

// %%
val letters2 = 'z' downTo 's' step 2
letters2
// Values: z, x, v, t
// Out:
// z downTo t step 2

// %% [markdown]
// ### Why Ranges Matter
// - Clean loop construction
// - Readable iteration logic
// - Supports numeric and character sequences
// - Functional-style iteration support

// %% [markdown]
// ### Loops
// - The two most common loop structures in programming are:
//   - `for`
//   - `while`

// %% [markdown]
// #### For
// Using ranges, you can create a `for` loop that iterates over a sequence of values.
//
// ### Syntax
// Place the iterator and the range inside parentheses `()` using the keyword `in`.
// Place the action inside curly braces `{}`.

// %%
for (number in 1..5) {
    // number is the iterator and 1..5 is the range
    print(number)
}
// 12345
// Out:
// 12345

// %% [markdown]
// Collections can also be iterated over by loops:

// %%
val cakes = listOf("carrot", "cheese", "chocolate")

for (cake in cakes) {
    println("Yummy, it's a $cake cake!")
}
// Yummy, it's a carrot cake!
// Yummy, it's a cheese cake!
// Yummy, it's a chocolate cake!
// Out:
// Yummy, it's a carrot cake!
// Yummy, it's a cheese cake!
// Yummy, it's a chocolate cake!

// %% [markdown]
// #### `while`
//
// `while` loops can be used in two ways:
//
// - **`while` loop**
//   → Checks the condition **before** executing the code block
// - **`do-while` loop**
//   → Executes the code block **first**, then checks the condition
//
// ---

// %% [markdown]
// `while`:
//
// - Declare the conditional expresion for you while loop within `()`
// - Add the action you want to complete within culry braces `{}`
//
// Example:

// %%
var cakesEaten = 0
while (cakesEaten < 3) {
    println("Eat a cake")
    cakesEaten++
}
// Eat a cake
// Eat a cake
// Eat a cake
// Out:
// Eat a cake
// Eat a cake
// Eat a cake

// %% [markdown]
// `do-while` :
// - Declare the conditional expression for your while loop to continue within `()`.
// - Define the action you want to complete within curly braces {} with the keyword `do`
//
// Example:

// %%
var cakesEaten = 0
var cakesBaked = 0
while (cakesEaten < 3) {
    println("Eat a cake")
    cakesEaten++
}

do {
    println("Bake a cake")
    cakesBaked++
} while (cakesBaked < cakesEaten)
// Out:
// Eat a cake
// Eat a cake
// Eat a cake
// Bake a cake
// Bake a cake
// Bake a cake

// %% [markdown]
// ## Null Safety in Kotlin
//
// - Kotlin allows variables to have a `null` value
// - `null` is used to represent **missing** or **unset** data
// - Example use case:
//   - Accessing a map with a non-existent key returns `null`
//
// ### Why Nulls Are Dangerous
// - Can cause runtime errors if not handled properly
// - Lead to crashes like `NullPointerException`
//
// ### Kotlin’s Solution: Null Safety
//
// Kotlin provides **null safety**, which detects null-related problems at **compile time** instead of runtime.
//
// ### Null Safety Features
//
// - Explicitly declare when `null` is allowed (`?`)
// - Check for `null` values
// - Use **safe calls** (`?.`) on nullable objects
// - Define **fallback actions** when `null` is detected (`?:`)
//
// ### Core Goal
// > Make null-related errors **visible early**, **handled safely**, and **prevent crashes**

// %% [markdown]
// ## Nullable Types in Kotlin
//
// - By default, Kotlin types **do not allow `null` values**
// - To allow `null`, the type must be **explicitly declared as nullable**
// - Nullable types are declared using `?` after the type
//
// ### Syntax
// ```kotlin
// val name: String? = null
// val age: Int? = 25

// %%
fun main() {
    // neverNull has String type
    var neverNull: String = "This can't be null"

    // Throws a compiler error
    neverNull = null
}

main()
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[18], line 3, column 9: Variable 'neverNull' is assigned but never accessed
// at Cell In[18], line 6, column 5: The value 'null' assigned to 'var neverNull: String defined in Line_20_jupyter.main' is never used
// at Cell In[18], line 6, column 17: Null can not be a value of a non-null type String
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:730)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:93)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:591)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:472)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx$lambda$0(ReplForJupyterImpl.kt:466)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:448)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:465)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0$0(IdeCompatibleMessageRequestProcessor.kt:161)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:351)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:364)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:341)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0(IdeCompatibleMessageRequestProcessor.kt:363)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:334)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:362)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:160)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl.executorThread$lambda$0(JupyterExecutorImpl.kt:81)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %%
fun main() {
    // nullable has nullable String type
    var nullable: String? = "You can keep a null here"

    // This is OK
    nullable = null
}

main()

// %%
// notNull doesn't accept null values
fun strLength(notNull: String): Int {
    return notNull.length
}
fun main() {
    // nullable has nullable String type
    var nullable: String? = "You can keep a null here"

    // This is OK
    nullable = null

    println(strLength(nullable))  // Throws a compiler error
}

main()
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[27], line 7, column 29: Variable 'nullable' initializer is redundant
// at Cell In[27], line 12, column 23: Type mismatch: inferred type is Nothing? but String was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:730)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:93)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:591)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:472)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx$lambda$0(ReplForJupyterImpl.kt:466)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:448)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:465)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0$0(IdeCompatibleMessageRequestProcessor.kt:161)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:351)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:364)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:341)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0(IdeCompatibleMessageRequestProcessor.kt:363)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:334)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:362)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:160)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl.executorThread$lambda$0(JupyterExecutorImpl.kt:81)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %%
// notNull doesn't accept null values
fun strLength(notNull: String?): Int {
    return notNull?.length ?: 0
}
fun main() {
    // nullable has nullable String type
    var nullable: String? = "You can keep a null here"

    // This is OK
    nullable = null

    println(strLength(nullable))  // Throws a compiler error
}

main()
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[7], line 3, column 19: Only safe (?.) or non-null asserted (!!.) calls are allowed on a nullable receiver of type String?
// at Cell In[7], line 7, column 29: Variable 'nullable' initializer is redundant
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:730)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-W38Nk0s(CellExecutorImpl.kt:93)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-W38Nk0s$default(CellExecutor.kt:14)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:591)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:472)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx$lambda$0(ReplForJupyterImpl.kt:466)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:448)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:465)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0$0(IdeCompatibleMessageRequestProcessor.kt:161)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:351)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:364)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:341)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO$lambda$0(IdeCompatibleMessageRequestProcessor.kt:363)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:124)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:334)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:362)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.processExecuteRequest$lambda$0$0(IdeCompatibleMessageRequestProcessor.kt:160)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl.executorThread$lambda$0(JupyterExecutorImpl.kt:81)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// ## Checking for Null Values in Kotlin
//
// - Kotlin allows you to check for `null` using **conditional expressions**
// - Null checks are commonly done with `if` statements
// - You can safely access properties only after confirming the value is not `null`

// %%
fun describeString(maybeString: String?): String {
    if (maybeString != null && maybeString.length > 0) {
        return "String of length ${maybeString.length}"
    } else {
        return "Empty or null string"
    }
}

// %% [markdown]
// ## References
// -  Chapter 2. Kotlin basics. Aigner, Sebastian, et al. Kotlin in action. Simon and Schuster, 2024.
// - Kotlin Foundation. “Kotlin Tour.” Kotlin Links to an external site.. Accessed 15 Jan. 2026.
