# %% [markdown]
# # Lab A2: Python Fundamentals

# %% [markdown]
# ## Exercise A2.1: Variables and Formatted Strings
#
# Complete the code to make the program print `Mary is 20 years old` to standard output:

# %%
def main():
    name = "Mary"
    age = 20

    # Write your code here


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.2: Python Basic Types
# Every value in Python has a data type. Python usually determines the type automatically from the assigned value.
#
# | Category | Python type | Explicit type annotation | Automatically recognized type |
# |---|---|---|---|
# | Integers | `int` | `year: int = 2026` | `year = 2026` |
# | Floating-point numbers | `float` | `price: float = 19.99` | `price = 19.99` |
# | Booleans | `bool` | `is_enabled: bool = True` | `is_enabled = True` |
# | Text | `str` | `message: str = "Hello"` | `message = "Hello"` |
# | Single character | `str` | `grade: str = "A"` | `grade = "A"` |
# | No value | `None` | `result: None = None` | `result = None` |

# %% [markdown]
# **Important**
# Python automatically recognizes the type from the assigned value. Therefore, both columns contain valid Python code.
# For example, these two statements create an integer variable:

# %%
# Explicit type annotation
year: int = 2026
print(year)
# Python automatically recognizes the type
year = 2026
print(year)
# Out:
# 2026
# 2026

# %% [markdown]
# Type annotations are optional in Python, but we will use them in this exercise to practice identifying the different data types.
#
# ### Practice
# Add the correct explicit Python type annotation to every variable. Do not change the assigned values.

# %%
def main():
    a: int = 1000
    b = "log message"
    c = 3.14
    d = 100_000_000_000_000
    e = False
    f = "\n"


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.3 - Control Flow: Dice Game
# Generate two dice results. Print `You win :)` when they are equal and `You lose :(` otherwise.
#
# For this exercise, import Python’s random module and use the randint() function:

# %%
import random

random.randint(1, 6)
# Out:
# 6

# %% [markdown]
# This generates a random integer from `1` through `6`, including both endpoints. Because the values are randomly generated, the results may be different each time you run the program.
# Use the equality operator `==` and an `if-else` statement to compare the two results.

# %%
import random


def main():
    first_result = random.randint(1, 6)
    second_result = random.randint(1, 6)

    # Write an if-else statement here
    # Compare the dice results and print the appropriate message


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.4 - Control Flow: Traffic Light

# %% [markdown]
# A traffic light can have one of the following states:
#
# | Traffic-light state | Action |
# |---|---|
# | `Green` | `Go` |
# | `Yellow` | `Slow down` |
# | `Red` | `Stop` |
# | Any other value | `Malfunction` |
#
# Use Python’s `match` statement to select the correct action for the current `traffic-light state`. Python’s `match` is similar to Kotlin’s `when` and Java’s `switch`.
# Complete the following program:

# %%
def main():
    traffic_light_state = "Red"

    # Use match and case to assign the correct value
    # to the traffic_action variable.
    # match traffic_light_state:

    print(traffic_action)


if __name__ == "__main__":
    main()

# %% [markdown]
# It is important to note that, In Python, `case _` represents the default case and runs when none of the previous cases match.

# %% [markdown]
# ## Exercise A2.5 - Loops: Pizza Slices
# You have a program that counts pizza slices until there's a whole pizza with 8 slices. Complete this program using `while`

# %%
def main():
    pizza_slices = 0

    # Write your loop here

    print(
        f"There are {pizza_slices} slices of pizza. "
        "Hooray! We have a whole pizza! :D"
    )


if __name__ == "__main__":
    main()
# Out:
# There are 0 slices of pizza. Hooray! We have a whole pizza! :D

# %% [markdown]
# ## Exercise A2.6 - Loops: FizzBuzz
# Write a program that simulates the [Fizz buzz game](https://en.wikipedia.org/wiki/Fizz_buzz). Your task is to print numbers from 1 to 100 incrementally, replacing any number divisible by three with the word "fizz", and any number divisible by five with the word "buzz". Any number divisible by both 3 and 5 must be replaced with the word "fizzbuzz".

# %% [markdown]
# >> **Hint 1**: Use a for loop to count numbers and an if elif else expression to decide what to print at each step.

# %% [markdown]
# >> **Hint 2**: Use the modulo operator (`%`) to return the remainder of a number being divided. Use the equality operator (`==`) to check if the remainder equals zero.

# %%
def main():
    #insert your code here

       
if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.7 - Loops: Words Beginning with “l”
#
# You have a list of words. Use  `for` and `if` to print only the words that start with the letter l.

# %% [markdown]
# >> **Hint 1**: Use the `.startswith()` function for String type.
#
# >> `str.startswith(prefix[, start[, end]])`
# Return True if string starts with the prefix, otherwise return False. prefix can also be a tuple of prefixes to look for. With optional start, test string beginning at that position. With optional end, stop comparing string at that position.

# %%
"Python".startswith("Py")
# Out:
# True

# %%
def main():
    words = ["dinosaur", "limousine", "magazine", "language"]

    # Use a for loop and an if statement


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.8 - Functions: Circle Area
# Write a function named circle_area() that receives an integer radius and returns the circle’s area.

# %% [markdown]
# >> Hint 1: The area of a circle is calculated using the formula $A = \pi r^2$ (pi times the radius squared)

# %%
from math import pi

print(pi)
# Out:
# 3.141592653589793

# %%
from math import pi


def circle_area(radius: int) -> float:
    # Return the area


def main():
    print(circle_area(2))


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.9 - Collections: Count List Items
# You have a list of “green” numbers and a list of “red” numbers. Complete the code to print how many numbers there are in total.

# %%
def main():
    green_numbers = [1, 4, 23]
    red_numbers = [17, 2]

    # Calculate and print the total


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.10 - Collections: Check A Set
# You have a set of protocols supported by your server. A user requests to use a particular protocol. Complete the program to check whether the requested protocol is supported or not (`isSupported` must be a Boolean value).

# %%
def main():
    SUPPORTED_PROTOCOLS = {"HTTP", "HTTPS", "FTP"}
    requested = "smtp"

    is_supported = # Write your code here

    print(f"Support for {requested}: {is_supported}")


if __name__ == "__main__":
    main()

# %% [markdown]
# >> **Hint 1**:
# Make sure that you check the requested protocol in upper case. You can use the `.upper()` function to help you with this.

# %%
"hello".upper()
# Out:
# 'HELLO'

# %% [markdown]
# ## Exercise A2.11 - Collections: Dictionaries
#
# Define a map that relates integer numbers from 1 to 3 to their corresponding spelling. Use this map to spell the given number.

# %%
def main():
    number_to_word = # Create the dictionary

    n = 2

    print(f"{n} is spelled as '{# Look up n in the dictionary}'")


if __name__ == "__main__":
    main()

# %% [markdown]
# ## Exercise A2.12 - Functions: Default and Named Arguments
#
# You have a function that translates a time interval given in hours, minutes, and seconds into seconds. In most cases, you need to pass only one or two function parameters while the rest are equal to 0. Improve the function and the code that calls it by using default parameter values and named arguments so that the code is easier to read.

# %%
def interval_in_seconds(hours: int, minutes: int, seconds: int) -> int:
    return ((hours * 60) + minutes) * 60 + seconds


def main():
    print(interval_in_seconds(1, 20, 15))
    print(interval_in_seconds(0, 1, 25))
    print(interval_in_seconds(2, 0, 0))
    print(interval_in_seconds(0, 10, 0))
    print(interval_in_seconds(1, 0, 1))


if __name__ == "__main__":
    main()
# Out:
# 4815
# 85
# 7200
# 600
# 3601

# %% [markdown]
# For example:
# `interval_in_seconds(minutes=10)`
